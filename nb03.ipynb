# %% [markdown]
# <a href="https://colab.research.google.com/github/imchihchao/aop113b/blob/main/nb03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Series

# %%
import pandas as pd

# 宣告建立一維資料 Series
age = [25, 30, 35, 40, 22, 29, 38, 27, 33, 31]
se = pd.Series(age)

# %%
se
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    22
# 5    29
# 6    38
# 7    27
# 8    33
# 9    31
# dtype: int64

# %%
se.values
se.index
se.dtype
# Out:
# dtype('int64')

# %%
# 自訂索引
name = ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack']
age = [25, 30, 35, 40, 22, 29, 38, 27, 33, 31]
seidx = pd.Series(age, index=name)
seidx
# Out:
# Alice      25
# Bob        30
# Charlie    35
# David      40
# Eve        22
# Frank      29
# Grace      38
# Helen      27
# Ivy        33
# Jack       31
# dtype: int64

# %%
seidx.index
# Out:
# Index(['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen',
#        'Ivy', 'Jack'],
#       dtype='object')

# %%
se[3]
# Out:
# np.int64(40)

# %%
se.loc[3]
# Out:
# np.int64(40)

# %%
se.iloc[3]
# Out:
# np.int64(40)

# %%
seidx.loc['David']
# Out:
# np.int64(40)

# %%
seidx.iloc[3]
# Out:
# np.int64(40)

# %% [markdown]
# ## DataFrame

# %%
import pandas as pd

data = {
    'ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack'],
    'Age': [25, 30, 35, 40, 22, 29, 38, 27, 33, 31],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose'],
    'Salary': [50000, 60000, 75000, 80000, 45000, 62000, 72000, 58000, 69000, 71000],
    'Department': ['IT', 'HR', 'Finance', 'Marketing', 'IT', 'HR', 'Finance', 'Marketing', 'IT', 'Finance']
}
df = pd.DataFrame(data)
df
# Out:
#     ID     Name  Age          City  Salary Department
# 0  101    Alice   25      New York   50000         IT
# 1  102      Bob   30   Los Angeles   60000         HR
# 2  103  Charlie   35       Chicago   75000    Finance
# 3  104    David   40       Houston   80000  Marketing
# 4  105      Eve   22       Phoenix   45000         IT
# 5  106    Frank   29  Philadelphia   62000         HR
# 6  107    Grace   38   San Antonio   72000    Finance
# 7  108    Helen   27     San Diego   58000  Marketing
# 8  109      Ivy   33        Dallas   69000         IT
# 9  110     Jack   31      San Jose   71000    Finance

# %%
df.values
df.index
df.columns
df.dtypes
# Out:
# ID             int64
# Name          object
# Age            int64
# City          object
# Salary         int64
# Department    object
# dtype: object

# %%
df.values[1]
# Out:
# array([102, 'Bob', 30, 'Los Angeles', 60000, 'HR'], dtype=object)

# %%
df.loc[1]
# Out:
# ID                    102
# Name                  Bob
# Age                    30
# City          Los Angeles
# Salary              60000
# Department             HR
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# ID                    102
# Name                  Bob
# Age                    30
# City          Los Angeles
# Salary              60000
# Department             HR
# Name: 1, dtype: object

# %%
df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# 6      Grace
# 7      Helen
# 8        Ivy
# 9       Jack
# Name: Name, dtype: object

# %%
df[['Name']]
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David
# 4      Eve
# 5    Frank
# 6    Grace
# 7    Helen
# 8      Ivy
# 9     Jack

# %% [markdown]
# ## 資料檢索

# %%
df
# Out:
#     ID     Name  Age          City  Salary Department
# 0  101    Alice   25      New York   50000         IT
# 1  102      Bob   30   Los Angeles   60000         HR
# 2  103  Charlie   35       Chicago   75000    Finance
# 3  104    David   40       Houston   80000  Marketing
# 4  105      Eve   22       Phoenix   45000         IT
# 5  106    Frank   29  Philadelphia   62000         HR
# 6  107    Grace   38   San Antonio   72000    Finance
# 7  108    Helen   27     San Diego   58000  Marketing
# 8  109      Ivy   33        Dallas   69000         IT
# 9  110     Jack   31      San Jose   71000    Finance

# %%
# 取得指定儲存格的值
df.values[2, 1] # [列,欄]
df.loc[2, 'Name']
df.iloc[2, 1]
# Out:
# 'Charlie'

# %%
# 指定範圍取值
df.iloc[2:6, 1:4]
# Out:
#       Name  Age          City
# 2  Charlie   35       Chicago
# 3    David   40       Houston
# 4      Eve   22       Phoenix
# 5    Frank   29  Philadelphia

# %%
# 注意 loc 和 iloc 的取值範圍
df.loc[2:6, 'Name':'Salary']
# Out:
#       Name  Age          City  Salary
# 2  Charlie   35       Chicago   75000
# 3    David   40       Houston   80000
# 4      Eve   22       Phoenix   45000
# 5    Frank   29  Philadelphia   62000
# 6    Grace   38   San Antonio   72000

# %%
df.head(3)
# Out:
#     ID     Name  Age         City  Salary Department
# 0  101    Alice   25     New York   50000         IT
# 1  102      Bob   30  Los Angeles   60000         HR
# 2  103  Charlie   35      Chicago   75000    Finance

# %%
dfidx = df.set_index('ID')
dfidx
# Out:
#         Name  Age          City  Salary Department
# ID
# 101    Alice   25      New York   50000         IT
# 102      Bob   30   Los Angeles   60000         HR
# 103  Charlie   35       Chicago   75000    Finance
# 104    David   40       Houston   80000  Marketing
# 105      Eve   22       Phoenix   45000         IT
# 106    Frank   29  Philadelphia   62000         HR
# 107    Grace   38   San Antonio   72000    Finance
# 108    Helen   27     San Diego   58000  Marketing
# 109      Ivy   33        Dallas   69000         IT
# 110     Jack   31      San Jose   71000    Finance

# %%
df
# Out:
#     ID     Name  Age          City  Salary Department
# 0  101    Alice   25      New York   50000         IT
# 1  102      Bob   30   Los Angeles   60000         HR
# 2  103  Charlie   35       Chicago   75000    Finance
# 3  104    David   40       Houston   80000  Marketing
# 4  105      Eve   22       Phoenix   45000         IT
# 5  106    Frank   29  Philadelphia   62000         HR
# 6  107    Grace   38   San Antonio   72000    Finance
# 7  108    Helen   27     San Diego   58000  Marketing
# 8  109      Ivy   33        Dallas   69000         IT
# 9  110     Jack   31      San Jose   71000    Finance

# %%
dfidx.loc[109]
# Out:
# Name             Ivy
# Age               33
# City          Dallas
# Salary         69000
# Department        IT
# Name: 109, dtype: object

# %%
condition = (df['Age'] > 30) | (df['Salary'] > 70000)

df[  (df['Age'] > 30) & (df['Salary'] > 70000)  ]
# Out:
#     ID     Name  Age         City  Salary Department
# 2  103  Charlie   35      Chicago   75000    Finance
# 3  104    David   40      Houston   80000  Marketing
# 6  107    Grace   38  San Antonio   72000    Finance
# 9  110     Jack   31     San Jose   71000    Finance

# %%
df.describe()
# Out:
#               ID        Age        Salary
# count   10.00000  10.000000     10.000000
# mean   105.50000  31.000000  64200.000000
# std      3.02765   5.656854  11193.251935
# min    101.00000  22.000000  45000.000000
# 25%    103.25000  27.500000  58500.000000
# 50%    105.50000  30.500000  65500.000000
# 75%    107.75000  34.500000  71750.000000
# max    110.00000  40.000000  80000.000000

# %%
df['Salary'].mean()
# Out:
# np.float64(64200.0)

# %%
df.count()
# Out:
# ID            10
# Name          10
# Age           10
# City          10
# Salary        10
# Department    10
# dtype: int64

# %%
df['Department'].unique()
# Out:
# array(['IT', 'HR', 'Finance', 'Marketing'], dtype=object)

# %%
df['Department'].value_counts()
# Out:
# Department
# IT           3
# Finance      3
# HR           2
# Marketing    2
# Name: count, dtype: int64

# %%
df['salary_rank'] = df['Salary'].rank()

# %%
df
# Out:
#     ID     Name  Age          City  Salary Department  salary_rank
# 0  101    Alice   25      New York   50000         IT          2.0
# 1  102      Bob   30   Los Angeles   60000         HR          4.0
# 2  103  Charlie   35       Chicago   75000    Finance          9.0
# 3  104    David   40       Houston   80000  Marketing         10.0
# 4  105      Eve   22       Phoenix   45000         IT          1.0
# 5  106    Frank   29  Philadelphia   62000         HR          5.0
# 6  107    Grace   38   San Antonio   72000    Finance          8.0
# 7  108    Helen   27     San Diego   58000  Marketing          3.0
# 8  109      Ivy   33        Dallas   69000         IT          6.0
# 9  110     Jack   31      San Jose   71000    Finance          7.0

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#     ID     Name  Age          City  Salary Department  salary_rank
# 3  104    David   40       Houston   80000  Marketing         10.0
# 6  107    Grace   38   San Antonio   72000    Finance          8.0
# 2  103  Charlie   35       Chicago   75000    Finance          9.0
# 8  109      Ivy   33        Dallas   69000         IT          6.0
# 9  110     Jack   31      San Jose   71000    Finance          7.0
# 1  102      Bob   30   Los Angeles   60000         HR          4.0
# 5  106    Frank   29  Philadelphia   62000         HR          5.0
# 7  108    Helen   27     San Diego   58000  Marketing          3.0
# 0  101    Alice   25      New York   50000         IT          2.0
# 4  105      Eve   22       Phoenix   45000         IT          1.0

# %%
df
# Out:
#     ID     Name  Age          City  Salary Department  salary_rank
# 0  101    Alice   25      New York   50000         IT          2.0
# 1  102      Bob   30   Los Angeles   60000         HR          4.0
# 2  103  Charlie   35       Chicago   75000    Finance          9.0
# 3  104    David   40       Houston   80000  Marketing         10.0
# 4  105      Eve   22       Phoenix   45000         IT          1.0
# 5  106    Frank   29  Philadelphia   62000         HR          5.0
# 6  107    Grace   38   San Antonio   72000    Finance          8.0
# 7  108    Helen   27     San Diego   58000  Marketing          3.0
# 8  109      Ivy   33        Dallas   69000         IT          6.0
# 9  110     Jack   31      San Jose   71000    Finance          7.0

# %%
df[['ID','Age','Salary']].sum(axis=1)
# Out:
# 0    50126
# 1    60132
# 2    75138
# 3    80144
# 4    45127
# 5    62135
# 6    72145
# 7    58135
# 8    69142
# 9    71141
# dtype: int64

# %%
grp = df.groupby('Department')

# %%
grp.get_group('IT')
# Out:
#     ID   Name  Age      City  Salary Department  salary_rank
# 0  101  Alice   25  New York   50000         IT          2.0
# 4  105    Eve   22   Phoenix   45000         IT          1.0
# 8  109    Ivy   33    Dallas   69000         IT          6.0

# %%
grp['Salary'].mean()
# Out:
# Department
# Finance      72666.666667
# HR           61000.000000
# IT           54666.666667
# Marketing    69000.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ## 資料清理

# %%
import pandas as pd

data = {
    'ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack'],
    'Age': [25, 30, 35, 40, 22, 29, 38, 27, 33, 31],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose'],
    'Salary': [50000, 60000, 75000, 80000, 45000, 62000, 72000, 58000, 69000, 71000],
    'Department': ['IT', 'HR', 'Finance', 'Marketing', 'IT', 'HR', 'Finance', 'Marketing', 'IT', 'Finance']
}
df = pd.DataFrame(data)
df
# Out:
#     ID     Name  Age          City  Salary Department
# 0  101    Alice   25      New York   50000         IT
# 1  102      Bob   30   Los Angeles   60000         HR
# 2  103  Charlie   35       Chicago   75000    Finance
# 3  104    David   40       Houston   80000  Marketing
# 4  105      Eve   22       Phoenix   45000         IT
# 5  106    Frank   29  Philadelphia   62000         HR
# 6  107    Grace   38   San Antonio   72000    Finance
# 7  108    Helen   27     San Diego   58000  Marketing
# 8  109      Ivy   33        Dallas   69000         IT
# 9  110     Jack   31      San Jose   71000    Finance

# %%
df['Company'] = 'TechCorp'

# %%
df
# Out:
#     ID     Name  Age          City  Salary Department   Company
# 0  101    Alice   25      New York   50000         IT  TechCorp
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp
# 3  104    David   40       Houston   80000  Marketing  TechCorp
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp

# %%
# 新增「年薪」欄位（假設每年有 12 個月薪資）
df['Annual Salary'] = df['Salary'] * 13.5
df
# Out:
#     ID     Name  Age          City  Salary Department   Company  Annual Salary
# 0  101    Alice   25      New York   50000         IT  TechCorp       675000.0
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp       810000.0
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp      1012500.0
# 3  104    David   40       Houston   80000  Marketing  TechCorp      1080000.0
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp       607500.0
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp       837000.0
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp       972000.0
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp       783000.0
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp       931500.0
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp       958500.0

# %%
# 新增「高薪」欄位（若薪資高於 65000 則標記為 Yes，否則為 No）
def high_salary(salary):
    if salary > 65000:
        return 'Yes'
    else:
        return 'No'

df['High Salary2'] = df['Salary'].apply(high_salary)
df
# Out:
#     ID     Name  Age          City  Salary Department   Company  \
# 0  101    Alice   25      New York   50000         IT  TechCorp
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp
# 3  104    David   40       Houston   80000  Marketing  TechCorp
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp
#
#    Annual Salary High Salary High Salary2
# 0       675000.0          No           No
# 1       810000.0          No           No
# 2      1012500.0         Yes          Yes
# 3      1080000.0         Yes          Yes
# 4       607500.0          No           No
# ...

# %%
# 刪除「City」與「Department」欄位
df.drop(columns=['High Salary2'], inplace=True)
df
# Out:
#     ID     Name  Age          City  Salary Department   Company  \
# 0  101    Alice   25      New York   50000         IT  TechCorp
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp
# 3  104    David   40       Houston   80000  Marketing  TechCorp
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp
#
#    Annual Salary High Salary
# 0       675000.0          No
# 1       810000.0          No
# 2      1012500.0         Yes
# 3      1080000.0         Yes
# 4       607500.0          No
# 5       837000.0          No
# 6       972000.0         Yes
# ...

# %%
df = df.drop(columns=['High Salary'])
df
# Out:
#     ID     Name  Age          City  Salary Department   Company  Annual Salary
# 0  101    Alice   25      New York   50000         IT  TechCorp       675000.0
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp       810000.0
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp      1012500.0
# 3  104    David   40       Houston   80000  Marketing  TechCorp      1080000.0
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp       607500.0
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp       837000.0
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp       972000.0
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp       783000.0
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp       931500.0
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp       958500.0

# %%
# 使用串列方式新增一筆資料（按照 DataFrame 欄位順序）
df.loc[len(df)] = [111, 'Kevin', 28, 'Austin', 67000, 'IT', 'TechCorp', 360000]
df
# Out:
#      ID     Name  Age          City  Salary Department   Company  \
# 0   101    Alice   25      New York   50000         IT  TechCorp
# 1   102      Bob   30   Los Angeles   60000         HR  TechCorp
# 2   103  Charlie   35       Chicago   75000    Finance  TechCorp
# 3   104    David   40       Houston   80000  Marketing  TechCorp
# 4   105      Eve   22       Phoenix   45000         IT  TechCorp
# 5   106    Frank   29  Philadelphia   62000         HR  TechCorp
# 6   107    Grace   38   San Antonio   72000    Finance  TechCorp
# 7   108    Helen   27     San Diego   58000  Marketing  TechCorp
# 8   109      Ivy   33        Dallas   69000         IT  TechCorp
# 9   110     Jack   31      San Jose   71000    Finance  TechCorp
# 10  111    Kevin   28        Austin   67000         IT  TechCorp
#
#     Annual Salary
# 0        675000.0
# 1        810000.0
# 2       1012500.0
# 3       1080000.0
# 4        607500.0
# 5        837000.0
# 6        972000.0
# 7        783000.0
# ...

# %%
new_data = [
    {'ID': 112, 'Name': 'Lily', 'Age': 26, 'City': 'Seattle', 'Salary': 55000, 'Department': 'Marketing'}
]
new_df = pd.DataFrame(new_data)
new_df
# Out:
#     ID  Name  Age     City  Salary Department
# 0  112  Lily   26  Seattle   55000  Marketing

# %%
df = pd.concat(  [df, new_df] ,ignore_index=True  )
df
# Out:
#      ID     Name  Age          City  Salary Department   Company  \
# 0   101    Alice   25      New York   50000         IT  TechCorp
# 1   102      Bob   30   Los Angeles   60000         HR  TechCorp
# 2   103  Charlie   35       Chicago   75000    Finance  TechCorp
# 3   104    David   40       Houston   80000  Marketing  TechCorp
# 4   105      Eve   22       Phoenix   45000         IT  TechCorp
# 5   106    Frank   29  Philadelphia   62000         HR  TechCorp
# 6   107    Grace   38   San Antonio   72000    Finance  TechCorp
# 7   108    Helen   27     San Diego   58000  Marketing  TechCorp
# 8   109      Ivy   33        Dallas   69000         IT  TechCorp
# 9   110     Jack   31      San Jose   71000    Finance  TechCorp
# 10  111    Kevin   28        Austin   67000         IT  TechCorp
# 11  112     Lily   26       Seattle   55000  Marketing       NaN
#
#     Annual Salary
# 0        675000.0
# 1        810000.0
# 2       1012500.0
# 3       1080000.0
# 4        607500.0
# ...

# %%
# 刪除索引為 2 的資料
df.drop(index=2, inplace=True)
df
# Out:
#      ID   Name  Age          City  Salary Department   Company  Annual Salary
# 0   101  Alice   25      New York   50000         IT  TechCorp       675000.0
# 1   102    Bob   30   Los Angeles   60000         HR  TechCorp       810000.0
# 3   104  David   40       Houston   80000  Marketing  TechCorp      1080000.0
# 4   105    Eve   22       Phoenix   45000         IT  TechCorp       607500.0
# 5   106  Frank   29  Philadelphia   62000         HR  TechCorp       837000.0
# 6   107  Grace   38   San Antonio   72000    Finance  TechCorp       972000.0
# 7   108  Helen   27     San Diego   58000  Marketing  TechCorp       783000.0
# 8   109    Ivy   33        Dallas   69000         IT  TechCorp       931500.0
# 9   110   Jack   31      San Jose   71000    Finance  TechCorp       958500.0
# 10  111  Kevin   28        Austin   67000         IT  TechCorp       360000.0
# 11  112   Lily   26       Seattle   55000  Marketing       NaN            NaN

# %%
condition = df['Salary'] < 75000
df = df[condition]
df
# Out:
#      ID   Name  Age          City  Salary Department   Company  Annual Salary
# 0   101  Alice   25      New York   50000         IT  TechCorp       675000.0
# 1   102    Bob   30   Los Angeles   60000         HR  TechCorp       810000.0
# 4   105    Eve   22       Phoenix   45000         IT  TechCorp       607500.0
# 5   106  Frank   29  Philadelphia   62000         HR  TechCorp       837000.0
# 6   107  Grace   38   San Antonio   72000    Finance  TechCorp       972000.0
# 7   108  Helen   27     San Diego   58000  Marketing  TechCorp       783000.0
# 8   109    Ivy   33        Dallas   69000         IT  TechCorp       931500.0
# 9   110   Jack   31      San Jose   71000    Finance  TechCorp       958500.0
# 10  111  Kevin   28        Austin   67000         IT  TechCorp       360000.0
# 11  112   Lily   26       Seattle   55000  Marketing       NaN            NaN

# %%
# 計算每一欄有多少個 NaN
df.isnull().sum()
# Out:
# ID               0
# Name             0
# Age              0
# City             0
# Salary           0
# Department       0
# Company          1
# Annual Salary    1
# dtype: int64

# %%
df.isnull()
# Out:
#        ID   Name    Age   City  Salary  Department  Company  Annual Salary
# 0   False  False  False  False   False       False    False          False
# 1   False  False  False  False   False       False    False          False
# 4   False  False  False  False   False       False    False          False
# 5   False  False  False  False   False       False    False          False
# 6   False  False  False  False   False       False    False          False
# 7   False  False  False  False   False       False    False          False
# 8   False  False  False  False   False       False    False          False
# 9   False  False  False  False   False       False    False          False
# 10  False  False  False  False   False       False    False          False
# 11  False  False  False  False   False       False     True           True

# %%
df[   df.isnull().any(axis=1)   ]
# Out:
#      ID  Name  Age     City  Salary Department Company  Annual Salary
# 11  112  Lily   26  Seattle   55000  Marketing     NaN            NaN

# %%
df.isnull().any(axis=0)
# Out:
# ID               False
# Name             False
# Age              False
# City             False
# Salary           False
# Department       False
# Company           True
# Annual Salary     True
# dtype: bool

# %%
df.columns[  df.isnull().any(axis=0) ]
# Out:
# Index(['Company', 'Annual Salary'], dtype='object')

# %%
df.loc[4,'Salary'] = pd.NA
df
# Out:
#      ID   Name  Age          City   Salary Department   Company  Annual Salary
# 0   101  Alice   25      New York  50000.0         IT  TechCorp       675000.0
# 1   102    Bob   30   Los Angeles  60000.0         HR  TechCorp       810000.0
# 4   105    Eve   22       Phoenix      NaN         IT  TechCorp       607500.0
# 5   106  Frank   29  Philadelphia  62000.0         HR  TechCorp       837000.0
# 6   107  Grace   38   San Antonio  72000.0    Finance  TechCorp       972000.0
# 7   108  Helen   27     San Diego  58000.0  Marketing  TechCorp       783000.0
# 8   109    Ivy   33        Dallas  69000.0         IT  TechCorp       931500.0
# 9   110   Jack   31      San Jose  71000.0    Finance  TechCorp       958500.0
# 10  111  Kevin   28        Austin  67000.0         IT  TechCorp       360000.0
# 11  112   Lily   26       Seattle  55000.0  Marketing       NaN            NaN

# %%
# 用平均數填充 Salary 欄位
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
df
# Out:
# <ipython-input-28-29c5ab0df49b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
#      ID   Name  Age          City        Salary Department   Company  \
# 0   101  Alice   25      New York  50000.000000         IT  TechCorp
# 1   102    Bob   30   Los Angeles  60000.000000         HR  TechCorp
# 4   105    Eve   22       Phoenix  62666.666667         IT  TechCorp
# 5   106  Frank   29  Philadelphia  62000.000000         HR  TechCorp
# 6   107  Grace   38   San Antonio  72000.000000    Finance  TechCorp
# 7   108  Helen   27     San Diego  58000.000000  Marketing  TechCorp
# 8   109    Ivy   33        Dallas  69000.000000         IT  TechCorp
# ...

# %%
df = df.dropna(axis=1)
df
# Out:
#      ID   Name  Age          City        Salary Department
# 0   101  Alice   25      New York  50000.000000         IT
# 1   102    Bob   30   Los Angeles  60000.000000         HR
# 4   105    Eve   22       Phoenix  62666.666667         IT
# 5   106  Frank   29  Philadelphia  62000.000000         HR
# 6   107  Grace   38   San Antonio  72000.000000    Finance
# 7   108  Helen   27     San Diego  58000.000000  Marketing
# 8   109    Ivy   33        Dallas  69000.000000         IT
# 9   110   Jack   31      San Jose  71000.000000    Finance
# 10  111  Kevin   28        Austin  67000.000000         IT
# 11  112   Lily   26       Seattle  55000.000000  Marketing

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=58d6040c-dca7-407f-a244-d0bfdfa8144a&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df
# Out:
#        sitename county  aqi pollutant    status   so2    co    o3  o3_8hr  \
# 0            基隆    基隆市   64     細懸浮微粒        普通   2.3  0.28  64.0      56
# 1            汐止    新北市   82     細懸浮微粒        普通  13.2  0.33  57.0      56
# 2            萬里    新北市   76     細懸浮微粒        普通   1.7  0.32  77.0      57
# 3            新店    新北市   81     細懸浮微粒        普通   1.7  0.39  76.0      60
# 4            土城    新北市   84     細懸浮微粒        普通   1.7  0.30  72.0      46
# ..          ...    ...  ...       ...       ...   ...   ...   ...     ...
# 82       屏東（琉球）    屏東縣   90     臭氧八小時        普通   1.2  0.24  70.0      67
# 83  台中市（和平區消防隊）    臺中市   67     細懸浮微粒        普通   0.6  0.28  67.0      52
# 84       新北（樹林）    新北市   89     細懸浮微粒        普通   NaN   NaN   NaN      31
# 85       臺南（南化）    臺南市   61     細懸浮微粒        普通   0.7  0.23  68.0      58
# 86       屏東(枋山)    屏東縣  118     臭氧八小時  對敏感族群不健康   1.1  0.24  98.0      76
#
#     pm10  ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# ...

# %% [markdown]
# ## 樞紐分析表

# %%
import pandas as pd

data = {
    'Department': ['Sales', 'Sales', 'HR', 'HR', 'IT', 'IT'],
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank'],
    'Salary': [5000, 5500, 4000, 4200, 6000, 6200],
    'Year': [2023, 2023, 2023, 2024, 2023, 2024]
}
df = pd.DataFrame(data)
df
# Out:
#   Department Employee  Salary  Year
# 0      Sales    Alice    5000  2023
# 1      Sales      Bob    5500  2023
# 2         HR  Charlie    4000  2023
# 3         HR    David    4200  2024
# 4         IT      Eve    6000  2023
# 5         IT    Frank    6200  2024

# %%
pd.pivot_table(df, index='Department', columns='Year', values='Salary', aggfunc='mean')
# Out:
# Year          2023    2024
# Department
# HR          4000.0  4200.0
# IT          6000.0  6200.0
# Sales       5250.0     NaN

# %% [markdown]
# ## 視覺化

# %%
# 下載台北黑體字型
# !wget -O taipei_sans_tc_beta.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download
# Out:
# --2025-04-15 08:26:59--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 74.125.132.102, 74.125.132.113, 74.125.132.139, ...
# Connecting to drive.google.com (drive.google.com)|74.125.132.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2025-04-15 08:26:59--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.126.132, 2607:f8b0:4001:c1d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.126.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘taipei_sans_tc_beta.ttf’
#
# taipei_sans_tc_beta 100%[===================>]  19.70M   114MB/s    in 0.2s
#
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.font_manager.fontManager.addfont('taipei_sans_tc_beta.ttf')
plt.rcParams['font.sans-serif'] = 'Taipei Sans TC Beta'
plt.rcParams["axes.unicode_minus"] = False

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'Year': [2020, 2021, 2022, 2023],
    'Sales': [100, 150, 200, 250]
}
df = pd.DataFrame(data)
df.plot(kind='bar', x='Year', y='Sales', title='年銷售額', figsize=(12, 4))
# Out:
# <Axes: title={'center': '年銷售額'}, xlabel='Year'>
